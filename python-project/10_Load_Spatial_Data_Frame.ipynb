# %% [markdown]
# # https://developers.arcgis.com/labs/python/load-spatial-data-frame/
# # Load Spatial Data Frame

# %%
from arcgis.gis import GIS
from arcgis.features import SpatialDataFrame
from IPython.display import display
import passwords

gis = GIS("https://www.arcgis.com", passwords.user_name, passwords.password)

search_results = gis.content.search(query='title: "Park*" AND type: "Feature Service"')
display(search_results)
# Out:
# [<Item title:"Parks and Open Space" type:Feature Layer Collection owner:jchaconsa>]

# %%
feature_service_item = search_results[0]
feature_layer = feature_service_item.layers[0]
display(feature_layer)
# Out:
# <FeatureLayer url:"https://services9.arcgis.com/CLnQFPrtUvD6IqqA/arcgis/rest/services/Parks_and_Open_Space/FeatureServer/0">

# %%
# Search for an item and construct a Spatial Data Frame

# %%
sdf = SpatialDataFrame.from_layer(feature_layer)
sdf.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\arcgis\features\feature.py:612: UserWarning: The SpatialDataFrame has been deprecated. `df` property will be removed as a future release. Use `sdf` instead.
#   warnings.warn(("The SpatialDataFrame has been deprecated. "
# C:\ProgramData\Anaconda3\lib\site-packages\arcgis\features\_data\geodataset\geodataframe.py:221: UserWarning: SpatialDataFrame has been deprecated.  Please switch to the GeoAccessor/GeoSeriesAccessor.
#   warnings.warn("SpatialDataFrame has been deprecated.  Please switch to the GeoAccessor/GeoSeriesAccessor.")
#    FID  UNIT_ID                                          PARK_NAME  \
# 0    1    12479  Unnamed site - Mountains Recreation and Conser...
# 1    2     6367                         Encino Reservoir - Federal
# 2    3    45791                            Crescent Place Triangle
# 3    4    12795    Santa Monica Mountains National Recreation Area
# 4    5    44333              Unnamed Site - Beverly Hills, City of
#
#                      PARK_LBL        ACCESS_TYP  RPT_ACRES  GIS_ACRES  \
# 0                                Unknown Access      6.224   6.223293
# 1  Encino Reservoir - Federal  No Public Access      1.470   1.470347
# 2     Crescent Place Triangle       Open Access      0.016   0.016226
# 3      Santa Monica Mtns. NRA       Open Access      1.804   1.804246
# 4                                   Open Access      3.459   3.458960
#
#                                         AGNCY_NAME         AGNCY_LEV  \
# 0  Mountains Recreation and Conservation Authority  Special District
# 1                                    Other Federal           Federal
# 2                             Los Angeles, City of              City
# 3              United States National Park Service           Federal
# 4                           Beverly Hills, City of              City
#
#              AGNCY_TYP  ... RSTRM TOTAL_GOOD TOTAL_FAIR TOTAL_POOR  \
# 0  Open Space District  ...     0          0          0          0
# 1       Federal Agency  ...     0          0          0          0
# 2          City Agency  ...     0          0          0          0
# 3       Federal Agency  ...     0          0          0          0
# 4          City Agency  ...     0          0          0          0
#
#                   TYPE Shape__Are Shape__Len   Shape__Area Shape__Length  \
# 0  Regional Open Space          0          0  36850.417969   1864.004664
# 1        Natural Areas          0          0   8706.011719    425.880474
# 2  Regional Open Space          0          0     95.746094     34.692429
# 3  Regional Open Space          0          0  10585.335938    431.938211
# 4        Natural Areas          0          0  20452.445312   1888.323740
#
#                                                SHAPE
# 0  {'rings': [[[-13207075.5355835, 4046453.651794...
# 1  {'rings': [[[-13192807.0616, 4046206.5301], [-...
# 2  {'rings': [[[-13187024.5001, 4027629.7172], [-...
# 3  {'rings': [[[-13206426.0243, 4041200.5067], [-...
# 4  {'rings': [[[-13180072.5545, 4038487.1192], [-...
#
# [5 rows x 46 columns]

# %%
# sdf.to_featureclass(out_location = 'path/to/save/data', out_name = 'file.shp')
